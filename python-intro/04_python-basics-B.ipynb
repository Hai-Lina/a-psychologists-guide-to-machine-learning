# %% [markdown]
# # A psychologist's guide to machine learning: Intro to Python
#
# This notebook was adapted from Lasser, J. (2025): "Technical Aspects of AI, microdegree AI and Society at the University of Graz". It can be used, modified, and redistributed under the terms of the [CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0) license.

# %% [markdown]
# # Python Basics B

# %% [markdown]
# ## Learning Objectives
# * Using conditions to influence the program flow.
# * Using and defining functions.
# * Working with explicit return values and default parameters of functions.
# * Using docstrings to explain or understand how functions work.
# * Understanding how modules work in Python and import modules to use the functions they provide.

# %% [markdown]
# ## Conditions
#
# In a program’s flow, it is often necessary to branch depending on certain states (for example, the current value of a variable). This is done using *conditions*.
#
# Before such a "branch," the program checks whether a condition is true or false, and then takes one path or the other.
#
# ![Condition](conditions.png)
#
# Let’s imagine we are programming an ATM:
#
# ~~~
# # This example uses pseudocode
#
# amount_to_withdraw = input('How much would you like to withdraw?')
#
# IF account_balance - amount_to_withdraw > overdraft_limit:
#     dispense money
# ELSE
#     error message: Your account balance is insufficient
# ~~~

# %% [markdown]
# The general form of a condition in Python (and most high-level programming languages) looks like this:
#
# ~~~
# if CONDITION == True:
#     do this
# else:  # CONDITION was not True
#     do something else
# ~~~
#
# The `else` part can be omitted.

# %%
# Here we create a "dataset" — a list of 100 names
# It would be easier to read this dataset from a file. How to do that
# will be explained in the next chapter.
names = [
    "Astrid", "Ines", "Christoph", "Markus", "Çınar", "Đželila", "Niklas",
    "Anna", "Stefanie", "Raphael", "Anna-Lena", "Silvia", "Julian", "Simon",
    "Katharina", "Michael", "Dominik", "Maria", "Kevin", "Bianca", "Thomas",
    "Nora", "Manuel", "Selina", "Gabriel", "Daniel", "Thomas", "Nina", "Michael",
    "Fabio", "Theresa", "Manuel", "Carina", "Philipp", "Lukas", "Wolfgang",
    "Anna", "Doris", "Thomas", "Muhammed", "Christoph", "Lisa-Marie", "Jessica",
    "Maria", "Thomas", "Florian", "Martin", "Anna", "Oliver", "Gregor", "Helmut",
    "Florian", "Matteo", "David", "Marlene", "Vanessa", "Lea", "Jan", "Béla",
    "Verena", "Manuel", "Björn", "Tobias", "Denise", "Emma", "Lukas", "Sarah",
    "Oliver", "Janine", "Manuel", "Georg", "Lorenz", "Verena", "Caroline",
    "Laura", "Felix", "Simon", "Lea", "Peter", "Sandra", "Julia", "Sophie",
    "Jacqueline", "Nina", "Sebastian", "David", "Matthias", "Patrick", "Selina",
    "Fabian", "Daniel", "Sabine", "Josef", "Lisa", "Carina", "Florian", "Fabian",
    "Viktoria", "Christoph", "Emilia"
]

# %% [markdown]
# ### if

# %% [markdown]
# As an example, let’s now determine all the names from our list that are longer than 8 characters:

# %%
# Note: the len() function returns the number of characters in a name
for name in names:
    if len(name) > 8:
        print(name)

# %% [markdown]
# ### if ... else

# %% [markdown]
# With `else`, we can handle all cases that do not meet the condition specified in `if`. In the following `else` section, we want to count how many names are shorter than or equal to 8 characters:

# %%
# we define two variables in which we store the number of
# short and long names, respectively
number_short_names = 0
number_long_names = 0

# we iterate through all the names in the list and increase the number stored
# in the respective variable by 1 whenever we find a name that meets
# the corresponding condition.
for name in names:
    if len(name) > 8:
        number_long_names = number_long_names + 1
    else:
        number_short_names = number_short_names + 1

# at the end, we print the number of short and long names
print(f"{number_short_names} short names and {number_long_names} long names")

# %% [markdown]
# ### Subconditions
#
# If conditions can be nested:

# %%
number_short_names = 0
number_medium_names = 0
number_long_names = 0

for name in names:
    # Name is longer than 8 characters
    if len(name) > 8:
        number_long_names = number_long_names + 1
    # Name is shorter than 9 characters
    else:
        if len(name) < 5:
            number_short_names = number_short_names + 1
        # here we count names with length >= 5 (because of the second "if")
        # and length <= 8 (because of the first "if")
        else:
            number_medium_names = number_medium_names + 1
print(f'{number_short_names} short names, {number_medium_names} names of medium length and {number_long_names} long names')

# %% [markdown]
# ### if ... elif ... else
#
# In Python, such nested conditions can often be avoided by using `elif`. Python goes through the sequence of conditions until the first one evaluates to `True`. All subsequent `elif`s and the `else` are then ignored:

# %%
number_short_names = 0
number_medium_names = 0
number_long_names = 0

for name in names:
    if len(name) > 8:
        number_long_names = number_long_names + 1
    elif len(name) < 5:
        number_short_names = number_short_names + 1
    else:
        number_medium_names = number_medium_names + 1

print(f'{number_short_names} short names, {number_medium_names} names of medium length {number_long_names} long names')

# %% [markdown]
# <font color='blue'><b>Exercise Conditions - 1</b></font>
# <font color='blue'>Go through, step by step in your mind, what happens in the code above. Use these names:</font>
# <pre>
#     ['Christopher', 'Anna', 'Elena']
# </pre>

# %% [markdown]
# <font color='purple'>**Optional (Advanced) / Conditions**</font>
# <ol class="outside">
# <font color='purple'><li>Consider the code in the following cell. Compare it with the code above and work out the differences.</li></font>
# <font color='purple'><li>Go through the list of names from "Exercise Conditions - 1" again using the following code. What's the resulting count for short, medium, and long names, respectively? Do you think this is what the author of the following code wanted to achieve?</li></font>
# </ol>

# %%
number_short_names = 0
number_medium_names = 0
number_long_names = 0

for name in names:
    if len(name) > 5:
        number_medium_names = number_medium_names + 1
    elif len(name) > 8:
        number_long_names = number_long_names + 1
    else:
        number_short_names = number_short_names + 1

# %% [markdown]
# When using `elif`, it is important to note that Python stops checking further conditions as soon as it encounters the first condition that evaluates to `True`. Therefore, you must pay attention to the correct order of the `if` and `elif` statements:

# %%
number = 40
if number < 100:
    print('number is smaller than 100')
elif number < 50:
  print('number is smaller than 50')

# %% [markdown]
# Although the condition in the `elif` evaluates to `True`, the corresponding text is not printed because another condition was already true earlier. Overlooking this is a common mistake.

# %% [markdown]
# ### The `in` Operator
# Some names appear multiple times in the list `names`. Depending on the question, this may or may not be desired. Let’s try to prevent duplicate names. For this, we need to introduce a new operator that tests whether a value is present in a sequence: `in`.

# %%
'a' in 'Anaconda'

# %% [markdown]
# `in` works with all iterables. Since lists are iterables, the `in` operator also works with lists. Here, we check whether the integer `42` appears in a list:

# %%
42 in [1, 55, 44, 32, 71, 41]

# %% [markdown]
# In the next example, we use the `in` operator to check whether the name already appears in a list of unique names:

# %%
unique_names = []

for name in names:
    if name in unique_names:
        pass  # do nothing
    else:
        unique_names.append(name)
print(f'List names: {len(names)} entries, list unique_names: {len(unique_names)} entries')

# %% [markdown]
# The `pass` in the fourth line of this example is a special feature of Python. After a colon (`if name in unique_names:`), there must be at least one statement. In the specific case of our example, nothing needs to be done if the name is already in `unique_names`. However, because of the colon in the previous line, we need to put a statement. This is exactly why Python has the `pass` statement. It is the equivalent of an empty pair of curly brackets in other programming languages:
#
# ~~~
# if(condition) {
# }
# ~~~

# %% [markdown]
# <font color='blue'><b>Exercise Conditions - 2</b></font>
# <font color='blue'>Modify the program above so that it checks whether the letter "j" appears in a name and stores all names containing the letter "j" in a list.</font>

# %%
# Your code here

# %% [markdown]
# If we use the inverse condition `not in` instead of `in`, we can omit the `else` in the example above:

# %%
unique_names = []
for name in names:
    if name not in unique_names:
        unique_names.append(name)
print(f'List names: {len(names)} entries, list unique_names: {len(unique_names)} entries')

# %% [markdown]
# ## Functions
#
# Functions are “subprograms” that are called from the main program. The advantages of using functions are:
#
# * Functions structure the code and make it easier to understand.
# * Functions are reusable: A function written once can be called multiple times at different places in a program. In principle, a function can also be “recycled” in other programs.
# * Functions prevent redundancy: Each functionality appears only once in the program. This makes the program easier to maintain and reduces the likelihood of errors.
#
# We recognize a function by its name, followed by parentheses. Typically, the function is *applied to an object*. The name of the object is given in the parentheses. This is also called the *argument* of the function.

# %%
# here we apply the function "len()" to the object "a_list"
a_list = [1, 2, 3, 4]
len(a_list)

# %% [markdown]
# During the course, we have already encountered some functions:
#
# * `print()` – outputs a string
# * `type()` – returns the type of an object
# * `len()` – returns the length of an object
#
# In each case, a function is called that someone else kindly wrote for us and that is available in every Python installation. However, we can also define our own functions.

# %% [markdown]
# ### Writing a Function
#
# A function definition in Python begins with the keyword `def` (many other languages use `function` instead). After `def` comes the name of the function. Ideally, this should be a verb, since a function always performs an action. The function name is followed by a pair of parentheses and a colon. After that, indented, comes the actual *function body*, which defines what the function does.

# %%
def say_hello():
    print('Hello!')

# %% [markdown]
# With this, we have written a function named `say_hello`. The function has been created during execution—our notebook now knows it exists—but it does not do anything yet because we have not called it. Calling the function looks like this:

# %%
say_hello()

# %% [markdown]
# ### Function Parameters
#
# The function `say_hello()` that we just wrote represents only the minimal version of a function: it always does the same thing. We can make the function more flexible by assigning **parameters** to it during its definition:

# %%
def say_hello(name):
    print(f'Hello {name}!')

# %% [markdown]
# Here, the function definition specifies that a *parameter* must be passed to the function when it is called. This value is then available within the function as the variable `name`. We can pass this value as an *argument* when calling the function:

# %%
say_hello('Otto')

# %%
say_hello('Anna')

# %% [markdown]
# ### Return Values
#
# Every function returns a value when called. This returned value essentially replaces the function call.
#
# The return value is specified using the `return` statement and should always appear at the end of the *function body*.

# %%
# define a function that takes a number as a parameter and
# returns the square of the number
def square(number):
    return number * number

# %%
square(2) + square(3)  # 4 + 9

# %% [markdown]
# If no `return` value is explicitly specified, the return value is always `None`, i.e., the "empty" value. Here is an example that illustrates this implicitly returned value:

# %%
def say_hello(name):
    print(f'Hello {name}!')

# %%
return_value = say_hello('Otto')  # saves the return value in a variable
print(f'Return value: {return_value}')

# %% [markdown]
# <font color='blue'><b>Exercise Functions - 1</b></font>
# <font color='blue'>Modify the function <tt>say_hello()</tt> so that it not only prints the variable <tt>name</tt> but also returns it.</font>

# %%
# Your code here

# %% [markdown]
# <font color='purple'>**Optional (Advanced) / Functions**</font>
#
# <font color='purple'>The function `say_hello()` is supposed to only work for strings. As it is written now, users can use the function with any data type
# (e.g., integers, lists, etc.), not only strings. Modify the function such that
# it only accepts strings as parameters. To achieve this, do the following:</font>
#
# <ol class="outside">
# <font color='purple'><li>Write an if condition that checks whether the entered parameter is <i>not</i> of type string. <b>Note</b>: Use the != operator and the type() function provided by Python in your if clause.</li>
# <li>If the condition is True print a warning, for example: "This function only accepts parameters of type string."</li>
# <li>Else proceed with the function body as above (i.e., print Hello name! and return the name parameter in addition).</li></font>
# </ol>

# %%
# Your code here

# %% [markdown]
# ### Explicit Return Values

# %% [markdown]
# Explicit return values are always useful when a function, for example, performs a calculation and the result of that calculation needs to be used in the main program.
#
# The following function transforms the given string so that only the first and last character are returned. Between these two characters, the number of omitted characters is placed. For example, `abcd` becomes `a2d`.

# %%
def shorten(long_string):
    # only useful for strings with more than 2 characters
    if len(long_string) > 2:

        # return the first (long_string[0]) and last character
        # (long_string[-1]) and in between the number
        # (len(long_string) - 2) of omitted characters
        return_value = f"{long_string[0]}{len(long_string) - 2}{long_string[-1]}"

    # if the string is short anyway, we simply return the string itself
    else:
        return_value = long_string
    return return_value

# %%
shorten("Christopher")

# %% [markdown]
# **Note**: Here we accessed individual elements in the string using index notation with square brackets <tt>[index]</tt>, which we discussed in the last chapter under "Lists" → "Accessing Individual Elements."

# %% [markdown]
# <font color='blue'><b>Exercise Functions - 2</b></font>
# <font color='blue'>Write a function that takes a list of numbers as a single argument and returns the sum of the squares of the numbers. Test the function with different lists containing numbers.</font>

# %%
# Your code here

# %% [markdown]
# ### Functions with Multiple Parameters

# %% [markdown]
# In principle, a function can have any number of parameters. In practice, unless there are very good reasons, one should limit it to a maximum of 3 or 4 parameters, as this makes the function easier to use (i.e., easier to understand).
#
# In the following example, we calculate the volume of a cuboid:

# %%
def calculate_volume(length, width, height):
  """Calculates the volume of a cuboid.

     Arguments
     length:   length in m
     width:    width in m
     height:   height in m

     Returns
     vol:      volume in m³
  """

  vol = length * width * height
  return vol

# %%
calculate_volume(0.8, 0.4, 0.4)

# %% [markdown]
# ### Docstrings
#
# In the function definition above, we saw a so-called "docstring" for the first time. It is usually used to describe the functionality of functions in detail: what the function does, which data types it expects as input parameters, and what it returns.
#
# A docstring is a string that can span multiple lines. It is enclosed with triple quotes <tt>"""</tt>.
#
# We can view the docstrings of functions using the help function:

# %%
# ?calculate_volume

# %% [markdown]
# ### Default Parameters
#
# Normally, the order of the arguments when calling a function must match the order of the parameters in the function declaration, and all arguments must be provided:
#
# ~~~
# def set_userdata(username, age):
#     ...
#
# set_userdata('otto', 20)
# ~~~
#
# If not all parameters are provided when calling the function, this will result in an error:

# %%
def set_userdata(name, age):
    return name, age

# %%
set_userdata('Hans')

# %% [markdown]
# If we do not require a parameter to be provided, we can assign a default value to it:

# %%
def set_userdata(name, age=None):
    return name, age

# %% [markdown]
# **Note**: In most programming languages, functions can return only a single value. In Python, however (as in the function above), two or more values can be returned directly.

# %%
print(set_userdata('otto', 20))
print(set_userdata('anna'))

# %% [markdown]
# If the value is provided, it is used in the function; otherwise, the default value is used. Such preassigned parameters must appear **after** all other parameters, which is why the following code does not work.

# %%
def set_userdata(age=None, name):
    return name, age

# %% [markdown]
# If more than one default parameter is defined, individual arguments can be addressed by their name when calling the function ("keyword arguments"), so we no longer have to follow the given order:

# %%
def set_userdata(name, age=None, weight=None, height=None):
    return name, age, weight, height

# %%
print(set_userdata('Otto', height=181))
print(set_userdata('Otto', height=181, age=25))

# %% [markdown]
# This is a pattern we will see very often: in machine learning, we frequently use functions that are already predefined and have many parameters. Very often, we only change a few of them and leave the other parameters at their default values, which are usually already set sensibly.

# %% [markdown]
# ## Modules

# %% [markdown]
# ### What Are Modules?
#
# Python organizes code into *modules*.
# A module is nothing more than a file with the `.py` extension.
#
# Modules are used to:
#
# * Organize large projects into smaller, more manageable files. Logically related pieces of code (e.g., functions and variables) are stored together in a single file (a *module*).
# * Make code more reusable, since modules can be selectively *imported* into new code.
#
# Small scripts can easily fit into a single file.
# However, once a program has more than a few hundred lines, it is recommended to split the code into multiple modules, also because this makes the code easier to maintain and test.

# %% [markdown]
# ### Modules Must Be Imported
#
# To use a module in your own program, the module must first be imported:
#
# ~~~
# import <module_name>
# ~~~
#
# After that, the module and its defined functionality are available.

# %% [markdown]
# ### The Standard Library
#
# Not only can your own program code be organized into modules, but external code is also distributed in modules. Every Python installation comes with the so-called "standard library." It contains a set of modules that are always available to us.
#
# The module `random`, included in the standard library, provides a number of functions for randomization. To use them, we first need to import the module:

# %%
import random

# %% [markdown]
# After that, we can, for example, use the function <tt>randint()</tt> to generate a random integer:

# %%
random.randint(0, 100)

# %% [markdown]
# ### Modules and Namespaces
#
# In the last example, we didn’t use just any function named `randint`, but specifically the one provided by the `random` module.
#
# Modules therefore not only structure code, but also create *namespaces*, which prevent, for example, two functions with the same name defined in different modules from overwriting each other.
#
# The namespace is simply formed by the module name. In the example above, that is <tt>random</tt>.

# %% [markdown]
# ### Renaming Namespaces
# Some namespace names are very long, making it tedious to type them repeatedly. Therefore, it is possible to assign a custom name to a module. This is done when we import the module. We assign the new name using the word <tt>as</tt>:

# %%
import random as rnd

# %%
rnd.randint(0, 100)

# %% [markdown]
# <font color='blue'><b>Exercise Modules</b></font>
# <font color='blue'>Another very useful module from the standard library is the <tt>math</tt> module, which provides basic mathematical functions such as the square root and constants like Pi.</font>
#
# <ul class="outside">
# <li><font color='blue'>Import the <tt>math</tt> module.</font></li>
# <li><font color='blue'>Check the <a href="https://docs.python.org/3/library/math.html">documentation</a> of the module to find the square root function.</font></li>
# <li><font color='blue'>Use the square root function to calculate the root of the number 2401.</font></li>
# <li><font color='blue'>Print the number <tt>Pi</tt> from the <tt>math</tt> module.</font></li>
# </ul>

# %%
# Your code here

# %% [markdown]
# ### Third-Party Libraries
#
# One of Python’s great strengths is the large ecosystem of developers who have created comprehensive and high-quality libraries for a wide range of use cases. Machine learning is just one example. These modules are called "third-party libraries."
#
# Like modules from the standard library, we must import these modules. Unlike the standard library, however, these modules often need to be installed in our *programming environment* before we can import them.
#
# The third-party libraries used in this course are:
#
# * <tt>pandas</tt> for working with datasets
# * <tt>seaborn</tt> and <tt>matplotlib</tt> for data visualization
# * <tt>scikit-learn</tt> for machine learning algorithms

# %%
# "pd" is the canonical abbreviation for pandas
import pandas as pd

# "sns" is the canonical abbreviation for seaborn
import seaborn as sns

# The module "scikit-learn" is imported under the short name
# "sklearn"
import sklearn

# %% [markdown]
# If we try to import a module that is not yet installed, this will result in an error:

# %%
import xgboost

# %% [markdown]
# We can install modules as shown below via "magic command". **Beware:** The exclamation mark at the beginning is important.

# %%
! pip install xgboost

# %%
import xgboost

# %% [markdown]
# ## Additional Materials
#
# * **Conditions**: [Introduction to Conditions](https://www.geeksforgeeks.org/python/conditional-statements-in-python/) from "Geeks for Geeks".
# * **Functions**: [Introduction to Functions](https://www.geeksforgeeks.org/python/python-functions/) from "Geeks for Geeks".
# * **Modules**: [Introduction to Modules](https://www.geeksforgeeks.org/python/python-modules/) from the course "Basics of Programming".
# * **Standard Library and Module Installation**: [Introduction to the Standard Library and the Python Package Index](https://www.geeksforgeeks.org/python/libraries-in-python/) from "Geeks for Geeks".
